# %% [markdown]
# # **starGAN_v2**
#
# > starGAN_v2's training code in colab.

# %% [markdown]
# 필요한 라이브러리 다운로드

# %%
# !pip install munch kornia ffmpeg torch torchvision opencv-python
# Out:
# ...
#      |████████████████████████████████| 309 kB 7.2 MB/s
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=8acd711ca38dc89f7fd6c24c0ca45428021980d1a7909d407f870258c1e1d8ea
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# ...

# %% [markdown]
# 데이터셋 다운로드

# %%
# !wget https://drive.google.com/file/d/12NJEch8MU6hnG3mMZSttJfCtDM2EULg4/view?usp=sharing
# Out:
# --2021-09-10 02:40:45--  https://drive.google.com/file/d/12NJEch8MU6hnG3mMZSttJfCtDM2EULg4/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 142.250.99.138, 142.250.99.139, 142.250.99.101, ...
# Connecting to drive.google.com (drive.google.com)|142.250.99.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing’
#
# view?usp=sharing        [ <=>                ]  64.11K  --.-KB/s    in 0.04s
#
# 2021-09-10 02:40:45 (1.55 MB/s) - ‘view?usp=sharing’ saved [65653]

# %% [markdown]
# 데이터셋이 있는 폴더로 이동

# %%
cd /content/drive/MyDrive/Colab Notebooks/starGAN/v2/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/starGAN/v2/data

# %% [markdown]
# 데이터셋 압축해제

# %%
# !unzip ./celeba_hq.zip

# %% [markdown]
# 코드가 있는 폴더로 이동

# %%
cd /content/drive/MyDrive/Colab Notebooks/starGAN/v2
# Out:
# /content/drive/MyDrive/Colab Notebooks/starGAN/v2

# %% [markdown]
# 학습 결과가 저장될 경로 지정

# %%
# !mkdir /content/drive/MyDrive/modulated_stargan_ckpt/
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/modulated_stargan_ckpt/’: File exists

# %% [markdown]
# > 초기 학습실행 코드

# %%
# !python main.py --img_size 512 --latent_dim 24 --style_dim 768 --val_batch_size 3 --mode train --num_domains 3 --w_hpf 0 --lambda_reg 1 --lambda_sty 1.3 --lambda_ds 2 --lambda_cyc 1.3 --train_img_dir data/afhq_v2/train --val_img_dir data/afhq_v2/val --batch_size 2 --sample_every 100 --save_every 500
# Out:
# Namespace(batch_size=2, beta1=0.0, beta2=0.99, checkpoint_dir='expr/checkpoints', ds_iter=100000, eval_dir='expr/eval', eval_every=50000, f_lr=1e-06, hidden_dim=512, img_size=512, inp_dir='assets/representative/custom/female', lambda_cyc=1.3, lambda_ds=2.0, lambda_reg=1.0, lambda_sty=1.3, latent_dim=24, lm_path='expr/checkpoints/celeba_lm_mean.npz', lr=0.0001, mode='train', num_domains=3, num_outs_per_domain=10, num_workers=4, out_dir='assets/representative/celeba_hq/src/female', print_every=10, randcrop_prob=0.5, ref_dir='assets/representative/celeba_hq/ref', result_dir='expr/results', resume_iter=0, sample_dir='expr/samples', sample_every=100, save_every=500, seed=777, src_dir='assets/representative/celeba_hq/src', style_dim=768, total_iters=100000, train_img_dir='data/afhq_v2/train', val_batch_size=3, val_img_dir='data/afhq_v2/val', w_hpf=0.0, weight_decay=0.0001, wing_path='expr/checkpoints/wing.ckpt')
# Number of parameters of generator: 38399587
# ...

# %% [markdown]
# > 학습 이어서 하는 명령어

# %%
# !python main.py --img_size 512 --resume_iter 41000 --latent_dim 24 --style_dim 768 --val_batch_size 3 --mode train --num_domains 3 --w_hpf 0 --lambda_reg 1 --lambda_sty 1.3 --lambda_ds 2 --lambda_cyc 1.3 --train_img_dir data/afhq_v2/train --val_img_dir data/afhq_v2/val --batch_size 2 --sample_every 100 --save_every 500
# Out:
# Namespace(batch_size=2, beta1=0.0, beta2=0.99, checkpoint_dir='expr/checkpoints', ds_iter=100000, eval_dir='expr/eval', eval_every=50000, f_lr=1e-06, hidden_dim=512, img_size=512, inp_dir='assets/representative/custom/female', lambda_cyc=1.3, lambda_ds=2.0, lambda_reg=1.0, lambda_sty=1.3, latent_dim=24, lm_path='expr/checkpoints/celeba_lm_mean.npz', lr=0.0001, mode='train', num_domains=3, num_outs_per_domain=10, num_workers=4, out_dir='assets/representative/celeba_hq/src/female', print_every=10, randcrop_prob=0.5, ref_dir='assets/representative/celeba_hq/ref', result_dir='expr/results', resume_iter=41000, sample_dir='expr/samples', sample_every=100, save_every=500, seed=777, src_dir='assets/representative/celeba_hq/src', style_dim=768, total_iters=100000, train_img_dir='data/afhq_v2/train', val_batch_size=3, val_img_dir='data/afhq_v2/val', w_hpf=0.0, weight_decay=0.0001, wing_path='expr/checkpoints/wing.ckpt')
# Number of parameters of generator: 38399587
# ...
